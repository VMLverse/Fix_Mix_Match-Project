# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Dec  9 12:14:33 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0    49W / 400W |   6304MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# Mount into drive

from google.colab import drive

drive.mount("/content/drive")

# %cd '/content/drive/MyDrive/Georgia Tech MSCS/CS 7643 Deep Learning/7643_final_project_colab/'

# !pip install -r requirements.txt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Georgia Tech MSCS/CS 7643 Deep Learning/7643_final_project_colab
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import csv
import torch
from IPython.display import Image
import argparse 

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from main import torch_check, run_all_experiments
torch_check()
# !ls

# parser = argparse.ArgumentParser() 
# parser.add_argument("--config", default="./config/config_fixmatch_cifar10_250.yaml") 

run_all_experiments()
# Out:
# You are using device: cuda
# Pytorch version:1.13.0+cu116
# checkpoints		  Experiments	  __pycache__	    training.py
# config			  issues.log	  README.md	    utils
# data			  main.py	  requirements.txt
# environment.yaml	  models	  result
# existing_implementations  notebook.ipynb  testing.py
# Config Parameters Loaded: Namespace(T=1, arch='wideresnet', batch_size=64, config='./config/config_fixmatch_cifar10red40_1000_cutoutonly.yaml', cutout_only=True, dataset='cifar10', ema_decay=0.999, eval_step=1024, lambda_u=1, lr=0.03, mu=7, nesterov=True, num_labeled=1000, num_workers=4, out='result/config_fixmatch_cifar10red40_1000_cutoutonly', reduced_data=40, resume=None, run_mixup=False, start_epoch=0, threshold=0.95, total_steps=102400, use_ema=True, warmup=0, wdecay='5e-4')
# Files already downloaded and verified
# Total params: 1.47M
# ***** Running training *****
#   Task = cifar10@1000
#   Num Epochs = 100
#   Total Batch Size = 64
#   Total optimization steps = 102400
# ...
